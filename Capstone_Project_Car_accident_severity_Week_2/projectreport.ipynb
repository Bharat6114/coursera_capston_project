# %% [markdown]
# # 1-INTRODUCTION/BUSINESS PROBLEM

# %% [markdown]
# Road accident is most unwanted thing to happen to a road user, though they happen quite often.
# The most unfortunate thing is that we don't learn from our mistakes on road.
# Most of the road users are quite well aware of the general rules and safety
# measures while using roads but it is only the laxity on part of road users,
# which cause accidents and crashes. Main cause of accidents and crashes are
# due to human errors. We are elaborating some of the common behaviour of humans which results in accident.
#
# 1.Over Speeding
#
# 2.Drunken Driving
#
# 3.Distractions to Driver
#
# 4.Red Light Jumping
#
# 5.Avoiding Safety Gears like Seat belts and Helmets
#
# 6.Non-adherence to lane driving and overtaking in a wrong manner
#
# Various national and international researches have found these as most common behavior of Road drivers,
# which leads to accidents.Aslo other factor such as road condition,weather,junction types etc cause road accidents.
# so i just want to find out which factor cause more accident and what can we do to avoid such factor to reduced road accident
# specially(car accident).After completion of this project i can suggest prevention method for road accident and form which many people can get knowledge of how we can reduced road accidents.
# For analysis of data i want to use following python library .
# 1-Pandas
# 2-Matplotlib
# 3- seaborn ect.

# %% [markdown]
# # 2-DATA

# %% [markdown]
# In this project i want to use data provided by coursera in the example as my data source to complete my project.link is as bellow
#
# Data :https://www.coursera.org/learn/applied-data-science-capstone/supplement/Nh5uS/downloading-example-dataset

# %% [markdown]
# # 3-METHODOLOGY

# %% [markdown]
# ![figure01_revised.jpg](attachment:figure01_revised.jpg)

# %% [markdown]
#                         Figure 1. Foundational methodology for data science.

# %% [markdown]
# # 1. Business understanding

# %% [markdown]
# Road accident is most unwanted thing to happen to a road user, though they happen quite often. The most unfortunate thing is that we don't learn from our mistakes on road. Most of the road users are quite well aware of the general rules and safety measures while using roads but it is only the laxity on part of road users, which cause accidents and crashes. Main cause of accidents and crashes are due to human errors. We are elaborating some of the common behaviour of humans which results in accident.
#
# 1.Over Speeding
#
# 2.Drunken Driving
#
# 3.Distractions to Driver
#
# 4.Red Light Jumping
#
# 5.Avoiding Safety Gears like Seat belts and Helmets
#
# 6.Non-adherence to lane driving and overtaking in a wrong manner
#
# Various national and international researches have found these as most common behavior of Road drivers, which leads to accidents.Aslo other factor such as road condition,weather,junction types etc cause road accidents. so i just want to find out which factor cause more accident and what can we do to avoid such factor to reduced road accident specially(car accident).After completion of this project i can suggest prevention method for road accident and form which many people can get knowledge of how we can reduced road accidents. For analysis of data i want to use following python library . 1-Pandas 2-Matplotlib 3- seaborn ect.

# %% [markdown]
# # 2. Analytic approach

# %% [markdown]
# For this we can use analytical approach to find whic factors are cause of the road accident so i want to plot different types of plot using
# pandas matplotlip and seaborn and suggest the prevention method.

# %% [markdown]
# # 3. DATA REQUIREMENT

# %% [markdown]
# Data is the one of the most essential component to make analysis so in this project
# i want to use data provided by course  in example as my data.

# %% [markdown]
# # 4.DATA COLLECTION

# %% [markdown]
# The data collectiion is one anothe most important part of the data science methodology so for this project i collect data provided by course and perform analyasis

# %% [markdown]
# # 5.DATA UNDERSTANDING

# %% [markdown]
# Data understanding is one another most important part of the data science methodology and it is also important to perform
# any activities is the data so underesting data palys a vital roal in any project.for this project i downoad data given in example
# and which oinclude 37 columns and nearly 194673 rows.this data include information of road ,type of junction,accident type,accident number ect.

# %% [markdown]
# # 6.DATA PREPERATION

# %% [markdown]
# After downloading data provided in the course example i perfornm verious data cleaning operation such as removing null value from data
# that help to make our analyasis mor easy and effective also i remove some columns from data because they contain many null values.And finally make data usefull
# for analysis and perform analyasis.

# %% [markdown]
# # 7.CONCLUSION

# %% [markdown]
# Afeter performing various typs of analyasis i found that most of the accident are occcures due to weat,ranning day and in the turning so
# i want to suggest to manke road with less turning and surface of the road is less water comnsuming surface.
