# %% [markdown]
# The following code is to import  python library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
print("All libraries are imported")
# Out:
# All libraries are imported

# %% [markdown]
# The following code is to load data

# %%
data = pd.read_csv("Data-Collisions.csv")
# Out:
# D:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (33) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# Code to print head of loaded data

# %%
data.head()
# Out:
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
# 3             1 -122.334803  47.604803         4    1144       1144  3503937
# 4             2 -122.306426  47.545739         5   17700      17700  1807429
#
#     STATUS      ADDRTYPE   INTKEY  ... ROADCOND                LIGHTCOND  \
# 0  Matched  Intersection  37475.0  ...      Wet                 Daylight
# 1  Matched         Block      NaN  ...      Wet  Dark - Street Lights On
# 2  Matched         Block      NaN  ...      Dry                 Daylight
# 3  Matched         Block      NaN  ...      Dry                 Daylight
# 4  Matched  Intersection  34387.0  ...      Wet                 Daylight
#
#   PEDROWNOTGRNT  SDOTCOLNUM SPEEDING ST_COLCODE  \
# ...

# %% [markdown]
# Code to get information about loaded data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194673 entries, 0 to 194672
# Data columns (total 38 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   SEVERITYCODE    194673 non-null  int64
#  1   X               189339 non-null  float64
#  2   Y               189339 non-null  float64
#  3   OBJECTID        194673 non-null  int64
#  4   INCKEY          194673 non-null  int64
#  5   COLDETKEY       194673 non-null  int64
#  6   REPORTNO        194673 non-null  object
#  7   STATUS          194673 non-null  object
#  8   ADDRTYPE        192747 non-null  object
#  9   INTKEY          65070 non-null   float64
#  10  LOCATION        191996 non-null  object
#  11  EXCEPTRSNCODE   84811 non-null   object
#  12  EXCEPTRSNDESC   5638 non-null    object
#  13  SEVERITYCODE.1  194673 non-null  int64
#  14  SEVERITYDESC    194673 non-null  object
#  15  COLLISIONTYPE   189769 non-null  object
# ...

# %%
data['SPEEDING'].value_counts()
# Out:
# Y    9333
# Name: SPEEDING, dtype: int64

# %%
data.drop('SPEEDING',axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194673 entries, 0 to 194672
# Data columns (total 37 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   SEVERITYCODE    194673 non-null  int64
#  1   X               189339 non-null  float64
#  2   Y               189339 non-null  float64
#  3   OBJECTID        194673 non-null  int64
#  4   INCKEY          194673 non-null  int64
#  5   COLDETKEY       194673 non-null  int64
#  6   REPORTNO        194673 non-null  object
#  7   STATUS          194673 non-null  object
#  8   ADDRTYPE        192747 non-null  object
#  9   INTKEY          65070 non-null   float64
#  10  LOCATION        191996 non-null  object
#  11  EXCEPTRSNCODE   84811 non-null   object
#  12  EXCEPTRSNDESC   5638 non-null    object
#  13  SEVERITYCODE.1  194673 non-null  int64
#  14  SEVERITYDESC    194673 non-null  object
#  15  COLLISIONTYPE   189769 non-null  object
# ...

# %%
data.isnull()
# Out:
#         SEVERITYCODE      X      Y  OBJECTID  INCKEY  COLDETKEY  REPORTNO  \
# 0              False  False  False     False   False      False     False
# 1              False  False  False     False   False      False     False
# 2              False  False  False     False   False      False     False
# 3              False  False  False     False   False      False     False
# 4              False  False  False     False   False      False     False
# ...              ...    ...    ...       ...     ...        ...       ...
# 194668         False  False  False     False   False      False     False
# 194669         False  False  False     False   False      False     False
# 194670         False  False  False     False   False      False     False
# 194671         False  False  False     False   False      False     False
# 194672         False  False  False     False   False      False     False
#
#         STATUS  ADDRTYPE  INTKEY  ...  WEATHER  ROADCOND  LIGHTCOND  \
# ...

# %%
data.dropna(axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194673 entries, 0 to 194672
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   SEVERITYCODE    194673 non-null  int64
#  1   OBJECTID        194673 non-null  int64
#  2   INCKEY          194673 non-null  int64
#  3   COLDETKEY       194673 non-null  int64
#  4   REPORTNO        194673 non-null  object
#  5   STATUS          194673 non-null  object
#  6   SEVERITYCODE.1  194673 non-null  int64
#  7   SEVERITYDESC    194673 non-null  object
#  8   PERSONCOUNT     194673 non-null  int64
#  9   PEDCOUNT        194673 non-null  int64
#  10  PEDCYLCOUNT     194673 non-null  int64
#  11  VEHCOUNT        194673 non-null  int64
#  12  INCDATE         194673 non-null  object
#  13  INCDTTM         194673 non-null  object
#  14  SDOT_COLCODE    194673 non-null  int64
#  15  SDOT_COLDESC    194673 non-null  object
#  16  SEGLANEKEY      194673 non-null  int64
# ...

# %%
usedata=data.head(n=2000)

# %%
usedata
# Out:
#       SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY  \
# 0                2 -122.323148  47.703140         1    1307       1307
# 1                1 -122.347294  47.647172         2   52200      52200
# 2                1 -122.334540  47.607871         3   26700      26700
# 3                1 -122.334803  47.604803         4    1144       1144
# 4                2 -122.306426  47.545739         5   17700      17700
# ...            ...         ...        ...       ...     ...        ...
# 1995             1 -122.333067  47.544302      2277  161700     161720
# 1996             1 -122.333430  47.608336      2278  190300     190380
# 1997             2 -122.366191  47.663651      2279   93200      93200
# 1998             1 -122.339072  47.571506      2280  167200     167220
# 1999             2 -122.300262  47.581118      2281   99600      99600
#
#      REPORTNO   STATUS      ADDRTYPE   INTKEY  ...   WEATHER ROADCOND  \
# ...

# %%
usedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 37 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SEVERITYCODE    2000 non-null   int64
#  1   X               1948 non-null   float64
#  2   Y               1948 non-null   float64
#  3   OBJECTID        2000 non-null   int64
#  4   INCKEY          2000 non-null   int64
#  5   COLDETKEY       2000 non-null   int64
#  6   REPORTNO        2000 non-null   object
#  7   STATUS          2000 non-null   object
#  8   ADDRTYPE        1985 non-null   object
#  9   INTKEY          700 non-null    float64
#  10  LOCATION        1975 non-null   object
#  11  EXCEPTRSNCODE   1041 non-null   object
#  12  EXCEPTRSNDESC   58 non-null     object
#  13  SEVERITYCODE.1  2000 non-null   int64
#  14  SEVERITYDESC    2000 non-null   object
#  15  COLLISIONTYPE   1910 non-null   object
#  16  PERSONCOUNT     2000 non-null   int64
# ...

# %%
usedata['ROADCOND'].value_counts().plot(kind='bar')

# %%
data['WEATHER'].value_counts().plot(kind='bar')

# %%
fig = plt.figure(figsize=(20,5))
sns.barplot(x=data['WEATHER'],y=data['SEVERITYCODE'].value_counts())

# %% [markdown]
# from above figure we can say most of the accident are happened in ranning day.

# %%
fig = plt.figure(figsize=(20,5))
sns.barplot(x=data['ROADCOND'],y=data['SEVERITYCODE'].value_counts())

# %% [markdown]
# from above analyasis we can say most of the accident are happened at wet road.

# %%
fig = plt.figure(figsize=(25,5))
sns.barplot(x=data['JUNCTIONTYPE'],y=data['SEVERITYCODE'].value_counts())

# %%
from above analysis we can say most of the accident are happened at mi
